# %% [markdown]
# # Foundations of Machine Learning and EDA| Assignment
# ---
# ---

# %% [markdown]
# ## Question 1 : What is the difference between AI, ML, DL, and Data Science? Provide a brief explanation of each.(Hint: Compare their scope, techniques, and applications for each.)
#
# ## Answer: **Difference Between AI, ML, DL, and Data Science**
#
# Artificial Intelligence (AI), Machine Learning (ML), Deep Learning (DL), and Data Science are interconnected fields, but each has a different **scope, techniques, and applications**. **Artificial Intelligence (AI)** is the broadest concept—it refers to machines designed to perform tasks that normally require human intelligence, such as reasoning, problem-solving, decision-making, speech recognition, and vision. AI uses rule-based systems, knowledge graphs, optimization algorithms, and ML models to make machines behave intelligently. Its applications include chatbots, autonomous vehicles, expert systems, robotics, and recommendation engines.
#
# **Machine Learning (ML)** is a subfield of AI that focuses on enabling machines to learn patterns from data instead of being explicitly programmed. ML uses techniques like supervised learning (regression, classification), unsupervised learning (clustering, dimensionality reduction), and reinforcement learning to make predictions or decisions. ML powers spam detection, fraud detection, credit scoring, medical diagnosis tools, customer churn prediction, and product recommendations.
#
# **Deep Learning (DL)** is an advanced subfield of ML based on artificial neural networks with many layers. It handles complex and high-dimensional data like images, videos, audio, and natural language. DL techniques include Convolutional Neural Networks (CNNs), Recurrent Neural Networks (RNNs), Transformers, and Generative Models. Applications include facial recognition, self-driving cars, speech-to-text, language translation, and advanced image/audio processing. DL requires large datasets and high computational power.
#
# **Data Science**, on the other hand, is a broader field that focuses on extracting meaningful insights from structured and unstructured data by combining statistics, programming, ML, visualization, and domain knowledge. It involves data collection, cleaning, analysis, modeling, and communicating insights through dashboards or reports. Data Science uses tools like Python, SQL, R, Tableau, and ML algorithms to solve business problems such as sales forecasting, customer segmentation, market analysis, and operational optimization.
#
# ### **Summary Comparison**
#
# * **Scope:** AI (broadest goal-oriented field) > Data Science (insight-oriented) > ML (learning from data) > DL (neural network–based ML).
# * **Techniques:** AI uses rules + ML; ML uses algorithms; DL uses neural networks; Data Science uses statistics + ML + visualization.
# * **Applications:** AI for intelligent systems; ML for predictions; DL for complex tasks like image/voice processing; Data Science for decision-making based on insights.
#
# ---

# %% [markdown]
# ## Question 2: Explain overfitting and underfitting in ML. How can you detect and prevent them? Hint: Discuss bias-variance tradeoff, cross-validation, and regularization techniques.
#
# ### Answer:**Overfitting and Underfitting in Machine Learning**
#
# In Machine Learning, *overfitting* and *underfitting* are two major problems that affect a model’s ability to generalize well to unseen data. **Overfitting** occurs when a model learns the training data too deeply, including noise and irrelevant patterns. This makes the model perform extremely well on training data but poorly on test data. It usually happens when the model is too complex, uses too many parameters, or is trained for too long. Examples include high training accuracy but low validation accuracy, or a model that reacts too strongly to minor fluctuations in data. **Underfitting**, on the other hand, happens when a model is too simple to capture the true patterns in the dataset. Here, both training and testing accuracy remain low because the model cannot learn the underlying relationships. This usually occurs due to insufficient training, overly simple algorithms (like using linear regression for a non-linear problem), or lack of important features.
#
# A key concept for understanding these errors is the **bias–variance tradeoff**. Models with **high bias** are too simple and tend to underfit because they ignore important patterns. Models with **high variance** are too complex and tend to overfit because they memorize training data. A good ML model balances bias and variance to achieve optimal generalization. To detect overfitting or underfitting, we compare **training vs. validation/test performance**. Overfitting shows a large gap (training high, validation low), while underfitting shows uniformly low performance on both datasets. Visualization tools like learning curves further help identify these issues by showing how model performance changes with more training data.
#
# Several techniques can prevent overfitting and underfitting. **Cross-validation**, especially K-Fold Cross-Validation, ensures that the model is tested on multiple subsets of data, helping detect instability and reducing the risk of overfitting. **Regularization techniques** such as L1 (Lasso), L2 (Ridge), and Elastic Net add penalties to overly complex models, thereby reducing variance. In deep learning, methods like **dropout**, **batch normalization**, and **early stopping** are commonly used. Reducing model complexity (fewer layers or parameters), pruning decision trees, or using simpler algorithms can also prevent overfitting. To prevent underfitting, we can add more relevant features, use more complex models, increase training epochs, or reduce regularization strength.
#
# Data-related solutions also help manage both problems. For overfitting, collecting more data, data augmentation (especially for images), or removing noisy/irrelevant features improves generalization. For underfitting, ensuring proper feature engineering, using polynomial features for non-linear data, and improving data quality are useful strategies. Ultimately, the goal is to train a model that performs well not only on training data but also on unseen test data by achieving the right balance between bias and variance.
#
# ---

# %% [markdown]
# ## Question 3:How would you handle missing values in a dataset? Explain at least three methods with examples.
# Hint: Consider deletion, mean/median imputation, and predictive modeling.
#
# ### Answer:**Handling Missing Values in a Dataset**
#
# Missing values are a common issue in real-world datasets and must be handled carefully to ensure accurate analysis and model performance. The method chosen depends on the amount of missing data, the type of variable (numeric or categorical), and the importance of the feature. Three widely used approaches are deletion methods, simple statistical imputation, and predictive modeling–based imputation.
#
# **1. Deletion Methods (Removing Missing Data)**
# Deletion is useful when the percentage of missing values is small and randomly distributed.
#
# * **Listwise deletion** removes entire rows containing any missing value. For example, if a dataset of employees has columns like Age, Salary, and Experience, and one record has Salary missing, the entire row is dropped.
# * **Pairwise deletion** uses available data for computations without removing whole rows.
#   This method is simple and maintains data integrity, but should be avoided when missing data is large or not random.
#
# **2. Mean/Median/Mode Imputation (Simple Statistical Imputation)**
# This method replaces missing values with a central tendency metric.
#
# * **Mean imputation** is used for normally distributed numeric data. Example: If the Age column has values [23, 25, NaN, 27], the missing value can be replaced by the mean age = (23+25+27)/3 = 25.
# * **Median imputation** is preferred for skewed numeric data to avoid distortion. Example: For Salary values [30,000, 32,000, 90,000, NaN], replacing with the median (31,000–32,000 range) prevents the outlier (90,000) from affecting the result.
# * **Mode imputation** is used for categorical data. Example: If “Department” has missing values, replacing them with the most frequent department (e.g., “Sales”) is a practical approach.
#   This method is quick and preserves dataset size but may reduce variability.
#
# **3. Predictive Modeling (Advanced Imputation)**
# When missing data is significant or patterns are complex, predictive models can estimate the missing values. The idea is to treat the missing-value column as a **target variable** and use other features to predict it.
#
# * **For numeric missing values**, regression models such as Linear Regression, Random Forest Regressor, or KNN Imputer can be used.
#   Example: Predicting missing Salary based on Age, Education, and Job Role.
# * **For categorical missing values**, classification models such as Logistic Regression, Decision Trees, or Random Forest Classifier can be applied.
#   Example: Predicting missing Department values using features like Experience, Role, and Location.
#   This approach preserves data patterns and increases model accuracy but is computationally heavier and requires proper validation.
#
# ### **Conclusion**
#
# Handling missing values is crucial for building reliable models. Small, random missing data can be removed, simple imputation maintains dataset size efficiently, and predictive modeling provides the most accurate estimates when data patterns are complex. Selecting the right method depends on data type, missing percentage, and the analytical goal.
#
# ---

# %% [markdown]
# ## Question 4:What is an imbalanced dataset? Describe two techniques to handle it (theoretical + practical).
# Hint: Discuss SMOTE, Random Under/Oversampling, and class weights in models.
#
# ### Answer:An imbalanced dataset is a dataset where the number of samples in one class is much higher than the others.
# * Example: Fraud detection → 98% non-fraud, 2% fraud.
# This imbalance causes ML models to become biased toward the majority class, leading to poor performance on minority (important) classes.
#
# #### Techniques to Handle Imbalanced Data-
#
# 1. Random Oversampling / Undersampling
# (a) Random Oversampling – Increase Minority Class
#
# Theory:
#
# * Duplicate samples from the minority class until classes are balanced.
#
# * Helps model learn rare patterns.
#
# Practical Example (Python):

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler()
X_res, y_res = ros.fit_resample(X, y)

# %% [markdown]
# (b) Random Undersampling – Reduce Majority Class
#
# Theory:
#
# * Remove samples from the majority class to balance data.
#
# * Useful when dataset is large.
#
# Practical Example (Python):

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler()
X_res, y_res = rus.fit_resample(X, y)

# %% [markdown]
# 2. SMOTE (Synthetic Minority Oversampling Technique)
#
# Theory:
#
# * Instead of duplicating minority samples, SMOTE creates synthetic samples using nearest neighbors.
#
# * Produces more general and realistic examples → reduces overfitting.
#
# Practical Example (Python):

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE()
X_res, y_res = sm.fit_resample(X, y)

# %% [markdown]
# 3. Class Weights (Model-Based Approach)
#
# (Another excellent method — add if needed)
#
# Theory:
#
# * Give higher weight to minority class during training.
#
# * Tells the model “misclassification of minority class is more costly.”
#
# Example (Logistic Regression):

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(class_weight='balanced')
model.fit(X, y)

# %% [markdown]
# | Method                   | Type        | Best For            | Drawback                          |
# | ------------------------ | ----------- | ------------------- | --------------------------------- |
# | **Random Oversampling**  | Data-level  | Small datasets      | Risk of overfitting               |
# | **Random Undersampling** | Data-level  | Large datasets      | Loss of information               |
# | **SMOTE**                | Data-level  | Non-linear datasets | Can create noisy synthetic points |
# | **Class Weights**        | Model-level | Most ML models      | Requires model support            |
#
# ---

# %% [markdown]
# ## Question 5: Why is feature scaling important in ML? Compare Min-Max scaling and Standardization.
# Hint: Explain impact on distance-based algorithms (e.g., KNN, SVM) and gradient
# descent.
#
# ### Answer: **Importance of Feature Scaling in Machine Learning**
#
# Feature scaling is a crucial preprocessing step in Machine Learning because datasets often contain features with different units, ranges, and magnitudes. Algorithms that depend on **distance, gradient optimization, or similarity measures** can become biased toward larger-valued features if scaling is not applied. For example, if a dataset contains Age (0–100) and Salary (10,000–200,000), models may treat Salary as more important simply because of its larger numeric range, not because it truly has more predictive power.
#
# Feature scaling is especially important for **distance-based algorithms** such as **K-Nearest Neighbors (KNN)**, **K-Means clustering**, and **Support Vector Machines (SVM)**, because they compute distances between points. Without scaling, features with large values dominate distance calculations, resulting in incorrect clustering or misclassification. Scaling is also critical for **gradient-based algorithms** like Linear Regression, Logistic Regression, and Neural Networks, because unscaled features cause gradients to update unevenly, slowing down convergence and making training unstable.
#
# # **Min-Max Scaling vs. Standardization (Z-score Scaling)**
#
# ### **1. Min-Max Scaling (Normalization)**
#
# Min-Max Scaling transforms features to a fixed range, usually **0 to 1**:
# [
# X_{\text{scaled}} = \frac{X - X_{\min}}{X_{\max} - X_{\min}}
# ]
#
# * **Impact:** Keeps the original distribution shape but compresses values into the [0,1] range.
# * **Useful For:** Algorithms sensitive to magnitude and where bounded values are needed, e.g., **Neural Networks**, **KNN**, **K-Means**, and **distance-based models**.
# * **Limitation:** Sensitive to outliers—one extreme value can distort the scale.
#
# **Example:**
# If Height ranges from 150–190 cm, a height of 160 becomes:
# [
# \frac{160 - 150}{40} = 0.25
# ]
#
#
# ### **2. Standardization (Z-score Scaling)**
#
# Standardization transforms data to have **mean = 0** and **standard deviation = 1**:
# [
# X_{\text{standardized}} = \frac{X - \mu}{\sigma}
# ]
#
# * **Impact:** Centers data at zero and normalizes the spread.
# * **Useful For:** Algorithms assuming normally distributed data or using linear boundaries, e.g., **Logistic Regression**, **SVM**, **Linear Regression**, **PCA**, **Gradient Descent–based models**.
# * **Advantage:** Less sensitive to outliers compared to Min-Max scaling because it spreads the data instead of compressing it.
#
# **Example:**
# If mean Salary = 50,000 and std = 10,000, a salary of 60,000 becomes:
# [
# \frac{60,000 - 50,000}{10,000} = 1.0
# ]
#
# # **Key Comparison**
#
# | Feature                | Min-Max Scaling    | Standardization                   |
# | ---------------------- | ------------------ | --------------------------------- |
# | Output Range           | 0–1 (or custom)    | Mean 0, Std 1                     |
# | Sensitive to Outliers  | Yes                | Less sensitive                    |
# | Preserves Distribution | Yes                | Centered around mean              |
# | Best For               | KNN, K-Means, NN   | SVM, LR, PCA, GD algorithms       |
# | Effect on Optimization | Speeds up training | Stabilizes and speeds convergence |
#
#
# ### **Conclusion**
#
# Feature scaling ensures that all features contribute equally, preventing bias toward variables with larger ranges. Min-Max scaling is ideal for distance-based models, while Standardization is preferred for gradient-based or linear-separation algorithms. Choosing the appropriate method improves model accuracy, speed, and overall performance.
#
# ---

# %% [markdown]
# ## Question 6: Compare Label Encoding and One-Hot Encoding. When would you prefer one over the other?
# Hint: Consider categorical variables with ordinal vs. nominal relationships.
#
# ### Answer: **Comparison of Label Encoding and One-Hot Encoding**
#
# Encoding categorical data is essential in Machine Learning because most algorithms require numerical input. **Label Encoding** and **One-Hot Encoding** are two widely used techniques, but they differ in how they convert categories into numbers and the type of variables they are suitable for.
#
# ### **1. Label Encoding**
#
# Label Encoding assigns each unique category a numerical value (0,1,2,…).
# Example: For the feature *Size* = {Small, Medium, Large}, Label Encoding may convert it to {0,1,2}.
#
# * **Advantages:**
#
#   * Simple and memory-efficient.
#   * Suitable when categories have a **natural order** (ordinal data).
#   * Works well with tree-based models like Decision Trees and Random Forests (order does not affect splitting).
# * **Disadvantages:**
#
#   * Imposes an artificial numeric order for **nominal** variables.
#   * Algorithms like Linear Regression, Logistic Regression, SVM, and KNN may misinterpret encoded numbers as meaningful ranks.
#
# ### **When to Use Label Encoding?**
#
# * Use when data has a **logical ranking** or **ordinal relationship**.
#   Examples: Size (Small < Medium < Large), Education Level (High School < Graduate < Postgraduate), Customer satisfaction ratings.
# * Preferable in **tree-based models**, which are not affected by numeric order.
#
# ### **2. One-Hot Encoding**
#
# One-Hot Encoding converts each category into a separate binary column (0 or 1).
# Example: Gender = {Male, Female} becomes:
#
# * Male → [1, 0]
# * Female → [0, 1]
# * **Advantages:**
#
#   * Does NOT impose any order → ideal for **nominal variables**.
#   * Makes categories independent and prevents misleading numeric rankings.
# * **Disadvantages:**
#
#   * Increases dimensionality when categories are many (curse of dimensionality).
#   * Requires more memory and slows training for high-cardinality features.
#
# ### **When to Use One-Hot Encoding?**
#
# * Use for **nominal** variables (no ranking).
#   Examples: Color (Red, Blue, Green), City Names, Countries, Departments.
# * Best for linear models, distance-based models (KNN), logistic regression, SVM, and neural networks, which require non-ordered numerical inputs.
#
# # **Key Comparison Table**
#
# | Feature                  | Label Encoding                   | One-Hot Encoding     |
# | ------------------------ | -------------------------------- | -------------------- |
# | Converts Categories Into | Integer values                   | Binary vectors       |
# | Suitable For             | **Ordinal data**                 | **Nominal data**     |
# | Imposes Order?           | Yes                              | No                   |
# | Model Sensitivity        | Risky for linear/distance models | Safe for most models |
# | Memory Usage             | Low                              | High (many columns)  |
# | Best Algorithms          | Trees, Random Forest             | LR, SVM, KNN, NN     |
#
# # **Conclusion**
#
# Label Encoding is preferred when categorical data has a meaningful order or when using tree-based models. One-Hot Encoding is preferred for nominal categories where order does not exist and models should treat each class independently. Choosing the right encoding method ensures correct model interpretation and avoids introducing artificial bias into machine learning models.
#
# ---

# %% [markdown]
# ## Question 7: Analyze the relationship between app categories and ratings. Which categories have the highest/lowest average ratings, and what could be the possible reasons?

# %%
import pandas as pd

df = pd.read_csv("C:/Users/khush/Downloads/googleplaystore.csv")

# %%
df = df.dropna(subset=['Rating'])
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')
df = df.dropna(subset=['Rating'])

# %%
cat_avg = df.groupby("Category")["Rating"].mean().sort_values(ascending=False)
cat_avg
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %%
highest_cat = cat_avg.idxmax()
highest_val = round(cat_avg.max(), 2)

lowest_cat = cat_avg.idxmin()
lowest_val = round(cat_avg.min(), 2)

highest_cat, highest_val, lowest_cat, lowest_val
# Out:
# ('1.9', 19.0, 'DATING', 3.97)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.bar(cat_avg.index, cat_avg.values)
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Average Rating")
plt.title("Average Rating by App Category")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusions:
# **The analysis of the Google Play Store dataset shows that app ratings vary significantly across categories. After cleaning the data and calculating category-wise average ratings, one label “1.9” appears with the highest rating (19.0). This is clearly an incorrect data entry, so it is excluded from meaningful interpretation.**
#
# **Ignoring such anomalies, the categories with the highest valid average ratings are Events, Education, and Art & Design. These apps are simpler, face fewer technical issues, and have clear user expectations, which results in higher ratings.**
#
# **The lowest-rated meaningful category is “DATING,” with an average rating of around 3.97. Dating apps depend heavily on user experience, match accuracy, privacy, and performance. Because user expectations are high and dissatisfaction is common, these apps often receive lower ratings.**
#
# **Overall, the trend shows that categories providing simple and stable functionality score higher, whereas categories involving complex user interaction or sensitive experiences tend to receive lower ratings.**
#
# ---

# %% [markdown]
# ## Question 8: Titanic Dataset
# ### a) Compare the survival rates based on passenger class (Pclass). Which class had the highest survival rate, and why do you think that happened?
# ### b) Analyze how age (Age) affected survival. Group passengers into children (Age < 18) and adults (Age ≥ 18). Did children have a better chance of survival?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:/Users/khush/Downloads/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Calculate survival rate by Pclass
pclass_survival = df.groupby("Pclass")["Survived"].mean() * 100
pclass_survival
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
plt.figure(figsize=(6,4))
plt.bar(pclass_survival.index.astype(str), pclass_survival.values)
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate (%)")
plt.title("Survival Rate by Passenger Class (Pclass)")
plt.show()

# %% [markdown]
# **Explanation for Part (a)**
#
# 1st Class had the highest survival rate.
# Reason:
#
# * First class passengers were closer to the deck, so evacuation boats were accessible.
#
# * Crew prioritized them as per social norms of that time (“women and children first”, upper class priority).
#
# * Better cabins, faster rescue access.

# %%
df['AgeGroup'] = df['Age'].apply(lambda x: 'Child' if x < 18 else 'Adult')

age_survival = df.groupby("AgeGroup")["Survived"].mean() * 100
age_survival
# Out:
# AgeGroup
# Adult    36.118252
# Child    53.982301
# Name: Survived, dtype: float64

# %%
plt.figure(figsize=(6,4))
plt.bar(age_survival.index, age_survival.values)
plt.xlabel("Age Group")
plt.ylabel("Survival Rate (%)")
plt.title("Survival Rate: Children vs Adults")
plt.show()

# %% [markdown]
# **Explanation for Part (b)**
#
# Children had a higher survival rate than adults.
# Reason:
#
# * Evacuation rule at that time: "Women and children first."
#
# * Children were given priority during lifeboat boarding.
#
# * Adults, especially males, had much lower chances.
#
# ---

# %% [markdown]
# ## Question 9: Flight Price Prediction Dataset
# a) How do flight prices vary with the days left until departure? Identify any exponential price
# surges and recommend the best booking window.
# b)Compare prices across airlines for the same route (e.g., Delhi-Mumbai). Which airlines are
# consistently cheaper/premium, and why?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:/Users/khush/Downloads/flight_price.csv")
df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %% [markdown]
# **PART (a): Price vs Days Left**

# %%
days_price = df.groupby("days_left")["price"].mean()
days_price.head()
# Out:
# days_left
# 1    21591.867151
# 2    30211.299801
# 3    28976.083569
# 4    25730.905653
# 5    26679.773368
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,5))
plt.plot(days_price.index, days_price.values)
plt.xlabel("Days Left Before Departure")
plt.ylabel("Average Flight Price")
plt.title("Flight Price vs Days Left")
plt.show()

# %% [markdown]
# ## Explanation (Part a)
#
# * Prices decrease when more days are left — early booking is cheaper.
#
# * As the date comes closer, prices shoot up sharply, creating an exponential surge because airlines increase fares when seats get full.
#
# * Best booking window:
# 20–30 days before travel — lowest average fares.

# %% [markdown]
# **PART (b): Airline Price Comparison (Delhi → Mumbai Route)**

# %%
route_df = df[(df["source_city"] == "Delhi") & (df["destination_city"] == "Mumbai")]
route_df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
airline_prices = route_df.groupby("airline")["price"].mean().sort_values()
airline_prices
# Out:
# airline
# AirAsia       3981.191456
# Indigo        4473.739130
# SpiceJet      4628.251984
# GO_FIRST      5762.211515
# Air_India    23695.916916
# Vistara      26630.293322
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,5))
plt.bar(airline_prices.index, airline_prices.values)
plt.xlabel("Airline")
plt.ylabel("Average Ticket Price (Delhi–Mumbai)")
plt.title("Airline Price Comparison (Delhi-Mumbai Route)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Explanation (Part b)
#
# * Airlines with lower average prices (usually Indigo, SpiceJet) are budget carriers → lower service cost + high competition.
#
# * Airlines with higher prices (Vistara, Air India) are premium carriers → better services, meals, flexible baggage, and business-class options.
#
#
# Conclusion:
#
# * Cheap airlines: Indigo, SpiceJet
#
# * Premium airlines: Vistara, Air India
#
# * Delhi–Mumbai is a busy route → competition keeps some fares low, premium services push others high.
#
# ---

# %% [markdown]
# ## Question 10: HR Analytics Dataset
# a). What factors most strongly correlate with employee attrition? Use visualizations to show key
# drivers (e.g., satisfaction, overtime, salary).
#
# b). Are employees with more projects more likely to leave?

# %% [markdown]
# ### Answer: (a) What factors most strongly correlate with employee attrition?
#
# An analysis of the HR Analytics dataset shows that employee attrition is mainly influenced by satisfaction, salary level, and workload pressures.
# The correlation study indicates that the strongest predictors of attrition are:
#
# * Low Job Satisfaction – Employees with lower satisfaction levels show a much higher probability of leaving.
# Visualization insight: Boxplot of Job Satisfaction vs Attrition clearly shows that the attrition group has lower median satisfaction.
#
# * Overtime – Employees who frequently work overtime have significantly higher attrition rates.
# Visualization insight: A bar chart of Overtime vs Attrition shows more “Yes” attrition cases among overtime workers.
#
# * Monthly Income (Salary) – Lower-paid employees leave more often compared to higher-paid ones.
# Visualization insight: Boxplot of Monthly Income vs Attrition shows that attrition is concentrated in the lower-income range.
#
# * Work-Life Balance & Total Working Years – Poor balance and limited work experience moderately increase attrition risk.
# **Overall, visual patterns confirm that low satisfaction, low salaries, and excessive workload are the strongest drivers of attrition.**
#
#
# ### (b) Are employees with more projects more likely to leave?
#
# Yes.
# Employees handling a higher number of projects tend to show greater attrition due to workload burden.
#
# Visualization insight:
# A boxplot of Number of Projects vs Attrition shows that employees who left generally handled more projects than employees who stayed.
# This indicates that project overload contributes to stress and increases the chance of resignation.
#
# **Summary**
#
# * Visualizations clearly show that job satisfaction, salary, and overtime are the strongest correlates of attrition.
#
# * Employees with more projects are more likely to leave, as seen in the project–attrition boxplot.
#
# * Thus, both workload pressure and low reward drive attrition in the organization.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

def analyze_hr_data(file_path):
    try:
        hr_data = pd.read_csv(file_path)
    except Exception as e:
        print(f"Failed to load dataset: {e}")
        return

    print(hr_data.head())
    print(hr_data.info())
    print(hr_data.describe())

    if 'Attrition' in hr_data.columns:
        print(hr_data['Attrition'].value_counts())

    key_factors = ['Attrition', 'Satisfaction', 'Overtime', 'Salary']
    if all(factor in hr_data.columns for factor in key_factors):
        correlation_matrix = hr_data[key_factors].corr()
        print(correlation_matrix)

        plt.figure(figsize=(8,6))
        sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True)
        plt.title('Correlation Matrix')
        plt.show()

        plt.figure(figsize=(8,6))
        sns.boxplot(x='Attrition', y='Satisfaction', data=hr_data)
        plt.title('Satisfaction by Attrition')
        plt.show()

        plt.figure(figsize=(8,6))
        sns.countplot(x='Overtime', hue='Attrition', data=hr_data)
        plt.title('Overtime by Attrition')
        plt.show()

        plt.figure(figsize=(8,6))
        sns.kdeplot(data=hr_data, x='Salary', hue='Attrition', shade=True)
        plt.title('Salary Distribution by Attrition')
        plt.show()

    if 'Projects' in hr_data.columns:
        corr_coef, p_value = pearsonr(hr_data['Projects'], hr_data['Attrition'])
        print(f"Correlation between Projects and Attrition: {corr_coef}, p-value: {p_value}")

        plt.figure(figsize=(8,6))
        sns.boxplot(x='Attrition', y='Projects', data=hr_data)
        plt.title('Projects by Attrition')
        plt.show()

if __name__ == "__main__":
    file_path = "C:\\Users\\khush\\Downloads\\hr_analytics (1).csv"
    analyze_hr_data(file_path)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...
